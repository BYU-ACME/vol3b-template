# %% [markdown]
# # Volume 2: Sampling
#     <Name>
#     <Class>
#     <Date>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import bernoulli, binom, beta

import pymc as pm
import arviz as az

# %% [markdown]
# ## Problem 1

# %%
def bernoulli_sampling(p, n):
    """
    Simulate n tosses of a coin which gives heads with probability p.
    Then use that sample to calculate the posterior distribution on p
    given a uniform prior.

    Parameters
    ----------
    p : float
        Probability of a successful Bernoulli trial (i.e., probability of heads).
    n : int
        Number of Bernoulli trials (coin tosses) to simulate.

    Returns
    -------
    float
        The MAP (maximum a posteriori) estimate of p based on the simulated data.
    """
    
    raise NotImplementedError("Problem 1 not complete")

# %% [markdown]
# ## Problem 2

# %%
def non_uniform_prior(p, n, prior):
    """
    Generate a sample of size n from a Bernoulli distribution with probability p.
    Use Bayes' theorem to compute the posterior distribution for the given prior
    and generated sample:

        P(t|x) ∝ P(x|t) * P(t)

    Plot both prior and posterior distributions between [0, 1].

    Parameters
    ----------
    p : float
        Probability of a successful Bernoulli trial.
    n : int
        Number of Bernoulli trials (sample size).
    prior : scipy.stats distribution
        The prior distribution on p, must have a .pdf() method (e.g., beta, uniform).

    Returns
    -------
    float
        The MAP (maximum a posteriori) estimate for p after observing the data.
    """
    
    raise NotImplementedError("Problem 2 not complete")

# %% [markdown]
# ## Problem 3

# %%
def weather_forecast(transition_matrix, days=10):
    """
    Simulate weather over a specified number of days using a Markov chain with a given transition matrix.
    Assume the first day (day 0) is always sunny.

    Parameters
    ----------
    transition_matrix : np.ndarray of shape (3, 3)
        A transition probability matrix where entry [i, j] gives the probability
        of moving from state i to state j. States are indexed as:
            0: sun
            1: rain
            2: wind
    days : int, optional
        The number of days to forecast after day 0 (default: 10).

    Returns
    -------
    list of str
        A forecast (length `days`) as a list of weather strings, each in {'sun', 'rain', 'wind'}.
    """
    
    raise NotImplementedError("Problem 3 not complete")

# %%
transition_matrix = np.array(
  [
    [0.6, 0.1, 0.3],
    [0.2, 0.6, 0.2],
    [0.3, 0.4, 0.3]
  ]
)

# %% [markdown]
# ## Problem 4

# %%
def posterior_sampling(data, n=1000):
    """
    Perform Bayesian inference for the probability of heads (p) given coin flip data,
    assuming a Bernoulli likelihood and a Beta(1,1) (uniform) prior. Uses PyMC to
    sample from the posterior and returns the posterior mean estimate.

    Parameters
    ----------
    data : array-like
        Sequence of observed coin flips (0 or 1).
    n : int, optional
        Number of samples to draw from the posterior (default: 1000).

    Returns
    -------
    float
        Posterior mean (expected value) of p, the probability of heads.
    """
    
    raise NotImplementedError("Problem 4 not complete")

# %%
data = bernoulli.rvs(0.2, size=100)

# %% [markdown]
# ## Problem 5

# %%
def height_model(observed_heights, m=180, s=10, alpha=2, beta=10, n=1000):
    """
    Perform Bayesian inference on the mean height (mu) and precision (tau) given
    observed heights, using a Normal-Gamma model and PyMC sampling.

    Parameters
    ----------
    observed_heights : array-like
        Observed data — measured heights of 100 men.
    m : float, optional
        Prior mean for mu (default: 180).
    s : float, optional
        Prior standard deviation for mu (default: 10).
    alpha : float, optional
        Shape parameter for prior on tau (default: 2).
    beta : float, optional
        Rate parameter for prior on tau (default: 10).
    n : int, optional
        Number of samples to draw from the posterior (default: 1000).

    Returns
    -------
    float
        Posterior mean (expected value) of mu, the estimated mean height.
    """
    
    raise NotImplementedError("Problem 5 not complete")

# %%
heights = np.random.normal(180, 10, 100)
